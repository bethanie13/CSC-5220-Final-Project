# %%
import scipy
import numpy
import matplotlib
import pandas
import sklearn
import seaborn as sb
# %matplotlib inline
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import matplotlib.pyplot as plt
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasRegressor
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import SGD
# Other machine learning modules
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
#We need to get rid of the md5 hash that since it is a string and all the other 
#features are floats
file_name = 'Kaggle-data.csv'
#When I originally did it there was one extra col that just had nan values so i removed the last one
num_cols=range(0,57)
dataset = read_csv(file_name, header=0, usecols=num_cols)
#Dropped the md5 hash column 
dataset = dataset.drop(['md5'], axis=1)
#Get the y values into a separate dataframe
y_vals = dataset.legitimate
# shows us the number of instances (rows) that belong to each class
print(dataset.groupby('legitimate').size())  
#Drop the y values from the original dataframe 
dataset = dataset.drop(['legitimate'], axis=1)

# 0 means malware, 1 means benign
# Out:
# legitimate
# 0    140849
# 1     75503
# dtype: int64

# %%
dataset.describe()
# Out:
#                   ID        Machine  SizeOfOptionalHeader  Characteristics  \
# count  216352.000000  216352.000000         216352.000000    216352.000000
# mean   108176.500000    3280.509836            225.389698      4658.171110
# std     62455.587057    9579.758901              4.554221      7844.088893
# min         1.000000     332.000000            176.000000         0.000000
# 25%     54088.750000     332.000000            224.000000       258.000000
# 50%    108176.500000     332.000000            224.000000       271.000000
# 75%    162264.250000     332.000000            224.000000      8450.000000
# max    216352.000000   43620.000000            352.000000     49551.000000
#
#        MajorLinkerVersion  MinorLinkerVersion    SizeOfCode  \
# count       216352.000000       216352.000000  2.163520e+05
# mean             8.899400            4.298070  3.953873e+05
# std              5.825682           11.965366  1.962775e+07
# min              0.000000            0.000000  0.000000e+00
# 25%              7.000000            0.000000  2.560000e+04
# 50%              9.000000            0.000000  1.018880e+05
# 75%             10.000000            0.000000  1.228800e+05
# max            255.000000          255.000000  4.294967e+09
#
#        SizeOfInitializedData  SizeOfUninitializedData  AddressOfEntryPoint  \
# count           2.163520e+05             2.163520e+05         2.163520e+05
# mean            5.827983e+05             1.332423e+06         2.812214e+05
# std             2.841106e+07             7.337809e+07         1.254327e+07
# min             0.000000e+00             0.000000e+00         0.000000e+00
# 25%             1.536000e+04             0.000000e+00         1.253800e+04
# 50%             1.198080e+05             0.000000e+00         4.661750e+04
# 75%             3.850240e+05             0.000000e+00         7.618000e+04
# max             4.294967e+09             4.294967e+09         4.127916e+09
#
#        ...       ExportNb    ResourcesNb  ResourcesMeanEntropy  \
# count  ...  216352.000000  216352.000000         216352.000000
# mean   ...      24.093205      21.311862              3.758008
# std    ...     267.169003     130.677344              1.270336
# min    ...       0.000000       0.000000              0.000000
# 25%    ...       0.000000       2.000000              3.362966
# 50%    ...       0.000000       6.000000              3.671986
# 75%    ...       0.000000      13.000000              4.194799
# max    ...   23986.000000    8215.000000              7.999723
#
#        ResourcesMinEntropy  ResourcesMaxEntropy  ResourcesMeanSize  \
# count        216352.000000        216352.000000       2.163520e+05
# mean              2.391040             5.149422       9.997023e+04
# std               1.042123             1.864446       1.718201e+07
# min               0.000000             0.000000       0.000000e+00
# 25%               2.010121             3.594461       7.755000e+02
# 50%               2.458492             5.217124       1.601958e+03
# 75%               3.003092             6.122045       3.146400e+03
# max               7.999723             8.000000       4.294903e+09
#
#        ResourcesMinSize  ResourcesMaxSize  LoadConfigurationSize  \
# count      2.163520e+05      2.163520e+05           2.163520e+05
# mean       7.139623e+04      2.524535e+05           1.023401e+06
# std        1.681531e+07      2.433613e+07           4.772522e+07
# min        0.000000e+00      0.000000e+00           0.000000e+00
# 25%        3.800000e+01      9.680000e+02           0.000000e+00
# 50%        4.800000e+01      7.336000e+03           0.000000e+00
# 75%        2.320000e+02      1.700500e+04           7.200000e+01
# max        4.294903e+09      4.294903e+09           4.294967e+09
#
#        VersionInformationSize
# count           216352.000000
# mean                 7.888492
# std                  8.049384
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                 15.000000
# max                 26.000000
#
# [8 rows x 55 columns]

# %%
dataset.corr()
# Out:
#                                    ID   Machine  SizeOfOptionalHeader  \
# ID                           1.000000 -0.089709             -0.089104
# Machine                     -0.089709  1.000000              0.987403
# SizeOfOptionalHeader        -0.089104  0.987403              1.000000
# Characteristics             -0.126395  0.072265              0.071759
# MajorLinkerVersion          -0.090089  0.030861              0.039354
# MinorLinkerVersion           0.015375 -0.084950             -0.076531
# SizeOfCode                  -0.007938  0.000696              0.070873
# SizeOfInitializedData       -0.002004 -0.002533              0.049669
# SizeOfUninitializedData     -0.013192 -0.005585             -0.005536
# AddressOfEntryPoint         -0.007222  0.004129              0.004061
# BaseOfCode                  -0.001100 -0.002695             -0.002666
# BaseOfData                  -0.004605 -0.011910             -0.011770
# ImageBase                   -0.004909  0.019770              0.019521
# SectionAlignment            -0.001958 -0.001640             -0.001627
# FileAlignment               -0.162527 -0.072492             -0.071543
# MajorOperatingSystemVersion -0.004481  0.000093              0.000081
# MinorOperatingSystemVersion -0.001750 -0.001042             -0.001039
# MajorImageVersion           -0.029514  0.048130              0.047479
# MinorImageVersion           -0.028642  0.046212              0.045626
# MajorSubsystemVersion       -0.208157  0.256671              0.252550
# MinorSubsystemVersion        0.004889  0.000400              0.000387
# SizeOfImage                  0.003190  0.004370              0.004248
# SizeOfHeaders               -0.022626 -0.019643             -0.019482
# CheckSum                     0.211336 -0.073760             -0.073129
# Subsystem                   -0.320107  0.187895              0.185383
# DllCharacteristics           0.415173 -0.184691             -0.183527
# SizeOfStackReserve          -0.002076  0.006981              0.006893
# SizeOfStackCommit           -0.002080  0.006985              0.006897
# SizeOfHeapReserve           -0.002120  0.006844              0.006758
# SizeOfHeapCommit             0.001205 -0.001622             -0.001608
# LoaderFlags                 -0.001917 -0.002074             -0.002056
# NumberOfRvaAndSizes          0.004087 -0.001526             -0.001513
# SectionsNb                   0.105216  0.036319              0.035249
# SectionsMeanEntropy          0.256566 -0.118885             -0.117788
# SectionsMinEntropy           0.169922 -0.020951             -0.020375
# SectionsMaxEntropy           0.424257 -0.239793             -0.237552
# SectionsMeanRawsize          0.002818  0.001879              0.001839
# SectionsMinRawsize          -0.026880  0.037572              0.037052
# SectionMaxRawsize            0.003470  0.001293              0.001260
# SectionsMeanVirtualsize      0.001579  0.002186              0.002142
# SectionsMinVirtualsize      -0.025535  0.036042              0.035542
# SectionMaxVirtualsize        0.002860  0.001530              0.001476
# ImportsNbDLL                -0.096059  0.071127              0.069381
# ImportsNb                   -0.032794  0.091918              0.089845
# ImportsNbOrdinal            -0.054643  0.061476              0.060581
# ExportNb                    -0.048101  0.043856              0.043219
# ResourcesNb                 -0.028025  0.043193              0.042508
# ResourcesMeanEntropy         0.250975 -0.023421             -0.024565
# ResourcesMinEntropy         -0.075881  0.101036              0.098774
# ResourcesMaxEntropy          0.335122 -0.079459             -0.079658
# ResourcesMeanSize           -0.000788 -0.001601             -0.001587
# ResourcesMinSize            -0.001749 -0.001298             -0.001287
# ResourcesMaxSize             0.002856 -0.002483             -0.002463
# LoadConfigurationSize       -0.007060 -0.006600             -0.006543
# VersionInformationSize       0.511307  0.231100              0.227293
#
#                              Characteristics  MajorLinkerVersion  \
# ID                                 -0.126395           -0.090089
# Machine                             0.072265            0.030861
# SizeOfOptionalHeader                0.071759            0.039354
# Characteristics                     1.000000           -0.215463
# MajorLinkerVersion                 -0.215463            1.000000
# MinorLinkerVersion                  0.350597           -0.222075
# SizeOfCode                          0.006158            0.048212
# SizeOfInitializedData               0.000895            0.032241
# SizeOfUninitializedData            -0.006256            0.007368
# AddressOfEntryPoint                 0.012908           -0.003785
# BaseOfCode                          0.024252            0.026763
# BaseOfData                          0.040868           -0.010109
# ImageBase                          -0.003584            0.002193
# SectionAlignment                   -0.002518            0.002448
# FileAlignment                      -0.031583           -0.080647
# MajorOperatingSystemVersion         0.000226            0.045440
# MinorOperatingSystemVersion         0.003649            0.056234
# MajorImageVersion                   0.018842            0.020800
# MinorImageVersion                   0.020238            0.020797
# MajorSubsystemVersion              -0.016944            0.300863
# MinorSubsystemVersion               0.000367           -0.001019
# SizeOfImage                         0.004623           -0.000323
# SizeOfHeaders                       0.005040           -0.031914
# CheckSum                            0.069701           -0.015288
# Subsystem                           0.115413            0.116672
# DllCharacteristics                 -0.448740            0.222230
# SizeOfStackReserve                 -0.001269           -0.000334
# SizeOfStackCommit                  -0.001263           -0.000333
# SizeOfHeapReserve                  -0.000489           -0.000584
# SizeOfHeapCommit                    0.013563           -0.005399
# LoaderFlags                         0.018272            0.009645
# NumberOfRvaAndSizes                 0.001105           -0.002750
# SectionsNb                          0.110934           -0.094592
# SectionsMeanEntropy                -0.404919            0.094815
# SectionsMinEntropy                 -0.274836            0.111033
# SectionsMaxEntropy                 -0.217173           -0.011725
# SectionsMeanRawsize                 0.006719           -0.002775
# SectionsMinRawsize                  0.016331            0.000849
# SectionMaxRawsize                   0.007749           -0.003267
# SectionsMeanVirtualsize             0.005352           -0.002914
# SectionsMinVirtualsize              0.017704           -0.000623
# SectionMaxVirtualsize               0.001200           -0.001450
# ImportsNbDLL                        0.204149           -0.075103
# ImportsNb                           0.028565           -0.048110
# ImportsNbOrdinal                   -0.002053           -0.001401
# ExportNb                            0.030852           -0.003019
# ResourcesNb                         0.087474           -0.020986
# ResourcesMeanEntropy               -0.046706            0.071237
# ResourcesMinEntropy                -0.013781            0.140788
# ResourcesMaxEntropy                -0.077261            0.022779
# ResourcesMeanSize                  -0.002910           -0.000004
# ResourcesMinSize                   -0.002365            0.000196
# ResourcesMaxSize                   -0.003526           -0.000483
# LoadConfigurationSize              -0.005389            0.016880
# VersionInformationSize              0.020352           -0.027587
#
#                              MinorLinkerVersion  SizeOfCode  \
# ID                                     0.015375   -0.007938
# Machine                               -0.084950    0.000696
# SizeOfOptionalHeader                  -0.076531    0.070873
# Characteristics                        0.350597    0.006158
# MajorLinkerVersion                    -0.222075    0.048212
# MinorLinkerVersion                     1.000000    0.049020
# SizeOfCode                             0.049020    1.000000
# SizeOfInitializedData                  0.021031    0.320853
# SizeOfUninitializedData                0.024871    0.134945
# AddressOfEntryPoint                    0.008945    0.001284
# BaseOfCode                             0.027716    0.218070
# BaseOfData                             0.007506    0.196505
# ImageBase                              0.000355    0.000070
# SectionAlignment                      -0.002375    0.000008
# FileAlignment                         -0.045773    0.011037
# MajorOperatingSystemVersion            0.032760   -0.000083
# MinorOperatingSystemVersion            0.056263   -0.000114
# MajorImageVersion                      0.000673    0.029767
# MinorImageVersion                      0.001899    0.044001
# MajorSubsystemVersion                 -0.142289   -0.002515
# MinorSubsystemVersion                  0.003746   -0.000090
# SizeOfImage                            0.000884    0.005357
# SizeOfHeaders                         -0.001067    0.002105
# CheckSum                               0.017564    0.001406
# Subsystem                             -0.064542   -0.001407
# DllCharacteristics                    -0.146429   -0.007083
# SizeOfStackReserve                    -0.000769   -0.000010
# SizeOfStackCommit                     -0.000773    0.000013
# SizeOfHeapReserve                     -0.000853    0.008537
# SizeOfHeapCommit                       0.002604    0.099918
# LoaderFlags                            0.020262    0.094460
# NumberOfRvaAndSizes                    0.006169    0.000028
# SectionsNb                             0.179542    0.003439
# SectionsMeanEntropy                   -0.244000    0.000994
# SectionsMinEntropy                    -0.268970   -0.000633
# SectionsMaxEntropy                    -0.025008   -0.000904
# SectionsMeanRawsize                   -0.003158    0.000786
# SectionsMinRawsize                    -0.015828   -0.000637
# SectionMaxRawsize                     -0.001415    0.000848
# SectionsMeanVirtualsize               -0.000177    0.001999
# SectionsMinVirtualsize                -0.013972   -0.000431
# SectionMaxVirtualsize                 -0.000613    0.002349
# ImportsNbDLL                           0.168844    0.012177
# ImportsNb                              0.011626    0.010194
# ImportsNbOrdinal                      -0.030334    0.007296
# ExportNb                              -0.012140    0.006128
# ResourcesNb                            0.011396    0.004996
# ResourcesMeanEntropy                  -0.038857   -0.005500
# ResourcesMinEntropy                   -0.076242   -0.004692
# ResourcesMaxEntropy                   -0.028155   -0.003430
# ResourcesMeanSize                     -0.001468    0.000245
# ResourcesMinSize                      -0.001460    0.000268
# ResourcesMaxSize                      -0.000527    0.000164
# LoadConfigurationSize                 -0.000989   -0.000263
# VersionInformationSize                -0.190963   -0.006280
#
#                              SizeOfInitializedData  SizeOfUninitializedData  \
# ID                                       -0.002004                -0.013192
# Machine                                  -0.002533                -0.005585
# SizeOfOptionalHeader                      0.049669                -0.005536
# Characteristics                           0.000895                -0.006256
# MajorLinkerVersion                        0.032241                 0.007368
# MinorLinkerVersion                        0.021031                 0.024871
# SizeOfCode                                0.320853                 0.134945
# SizeOfInitializedData                     1.000000                 0.097395
# SizeOfUninitializedData                   0.097395                 1.000000
# AddressOfEntryPoint                       0.001307                 0.000690
# BaseOfCode                                0.171767                 0.040280
# BaseOfData                                0.153370                 0.082713
# ImageBase                                 0.000034                -0.000110
# SectionAlignment                         -0.000085                -0.000123
# FileAlignment                             0.001639                 0.001533
# MajorOperatingSystemVersion              -0.000120                -0.000154
# MinorOperatingSystemVersion              -0.000117                -0.000147
# MajorImageVersion                         0.024663                 0.010478
# MinorImageVersion                         0.045910                 0.017828
# MajorSubsystemVersion                    -0.005800                -0.012158
# MinorSubsystemVersion                    -0.000073                -0.000106
# SizeOfImage                               0.092431                 0.000930
# SizeOfHeaders                             0.000077                 0.005392
# CheckSum                                 -0.001047                -0.004327
# Subsystem                                -0.007392                -0.007660
# DllCharacteristics                       -0.008680                -0.015470
# SizeOfStackReserve                       -0.000026                -0.000033
# SizeOfStackCommit                         0.000005                -0.000023
# SizeOfHeapReserve                         0.006261                 0.003273
# SizeOfHeapCommit                          0.124824                 0.045511
# LoaderFlags                               0.089695                 0.046494
# NumberOfRvaAndSizes                       0.000006                -0.000082
# SectionsNb                               -0.001066                 0.004670
# SectionsMeanEntropy                       0.007075                 0.008746
# SectionsMinEntropy                        0.005983                 0.000014
# SectionsMaxEntropy                        0.003550                 0.003497
# SectionsMeanRawsize                       0.002330                 0.000059
# SectionsMinRawsize                        0.010334                -0.000480
# SectionMaxRawsize                         0.002098                 0.000071
# SectionsMeanVirtualsize                   0.051361                 0.000390
# SectionsMinVirtualsize                    0.010526                -0.000413
# SectionMaxVirtualsize                     0.058406                 0.000380
# ImportsNbDLL                             -0.002839                 0.010456
# ImportsNb                                 0.003124                 0.001737
# ImportsNbOrdinal                          0.002965                -0.002317
# ExportNb                                  0.001146                -0.001619
# ResourcesNb                               0.010827                -0.001419
# ResourcesMeanEntropy                     -0.002709                -0.001735
# ResourcesMinEntropy                      -0.007036                -0.007986
# ResourcesMaxEntropy                       0.001968                 0.006992
# ResourcesMeanSize                        -0.000007                -0.000082
# ResourcesMinSize                         -0.000060                -0.000063
# ResourcesMaxSize                          0.001065                -0.000109
# LoadConfigurationSize                    -0.000326                -0.000386
# VersionInformationSize                   -0.006692                -0.017376
#
#                              AddressOfEntryPoint  ...  ExportNb  ResourcesNb  \
# ID                                     -0.007222  ... -0.048101    -0.028025
# Machine                                 0.004129  ...  0.043856     0.043193
# SizeOfOptionalHeader                    0.004061  ...  0.043219     0.042508
# Characteristics                         0.012908  ...  0.030852     0.087474
# MajorLinkerVersion                     -0.003785  ... -0.003019    -0.020986
# MinorLinkerVersion                      0.008945  ... -0.012140     0.011396
# SizeOfCode                              0.001284  ...  0.006128     0.004996
# SizeOfInitializedData                   0.001307  ...  0.001146     0.010827
# SizeOfUninitializedData                 0.000690  ... -0.001619    -0.001419
# AddressOfEntryPoint                     1.000000  ...  0.005526     0.003712
# BaseOfCode                              0.008480  ... -0.000728     0.000970
# BaseOfData                              0.017507  ...  0.011202     0.012602
# ImageBase                               0.000978  ... -0.000514    -0.000945
# SectionAlignment                        0.057380  ... -0.000373    -0.000743
# FileAlignment                           0.002393  ...  0.048717    -0.006001
# MajorOperatingSystemVersion            -0.000134  ... -0.000248    -0.000585
# MinorOperatingSystemVersion            -0.000114  ... -0.000511    -0.000872
# MajorImageVersion                       0.000630  ...  0.017055    -0.006865
# MinorImageVersion                       0.000677  ...  0.016367    -0.006934
# MajorSubsystemVersion                  -0.005451  ...  0.030122     0.006788
# MinorSubsystemVersion                  -0.000105  ... -0.000147    -0.000279
# SizeOfImage                             0.067417  ...  0.023898     0.067129
# SizeOfHeaders                           0.002236  ...  0.012483     0.002018
# CheckSum                               -0.004730  ... -0.021341    -0.019421
# Subsystem                              -0.002215  ...  0.022168    -0.017573
# DllCharacteristics                     -0.009543  ... -0.097042    -0.086281
# SizeOfStackReserve                     -0.000014  ... -0.000194    -0.000351
# SizeOfStackCommit                      -0.000014  ... -0.000194    -0.000351
# SizeOfHeapReserve                      -0.000010  ... -0.000220    -0.000359
# SizeOfHeapCommit                       -0.000056  ... -0.000471    -0.000834
# LoaderFlags                            -0.000021  ... -0.000600    -0.001049
# NumberOfRvaAndSizes                    -0.000084  ... -0.000447    -0.000593
# SectionsNb                              0.003306  ...  0.070879    -0.033070
# SectionsMeanEntropy                    -0.002561  ...  0.028395     0.026374
# SectionsMinEntropy                     -0.006387  ...  0.006874     0.030501
# SectionsMaxEntropy                      0.004162  ... -0.017072    -0.029502
# SectionsMeanRawsize                     0.001295  ...  0.003535     0.028400
# SectionsMinRawsize                     -0.000833  ... -0.001804     0.314583
# SectionMaxRawsize                       0.001178  ...  0.003809     0.013330
# SectionsMeanVirtualsize                 0.015616  ...  0.006610     0.057008
# SectionsMinVirtualsize                 -0.000445  ... -0.001798     0.315889
# SectionMaxVirtualsize                   0.020569  ...  0.009062     0.034226
# ImportsNbDLL                            0.005484  ...  0.054441     0.067096
# ImportsNb                               0.003724  ...  0.219290     0.178205
# ImportsNbOrdinal                        0.001159  ...  0.066253     0.138577
# ExportNb                                0.005526  ...  1.000000     0.034550
# ResourcesNb                             0.003712  ...  0.034550     1.000000
# ResourcesMeanEntropy                   -0.002294  ... -0.018927     0.046293
# ResourcesMinEntropy                    -0.011891  ... -0.006099    -0.174090
# ResourcesMaxEntropy                     0.000981  ... -0.022252     0.141270
# ResourcesMeanSize                      -0.000031  ... -0.000411    -0.000769
# ResourcesMinSize                       -0.000018  ... -0.000314    -0.000660
# ResourcesMaxSize                        0.000295  ... -0.000658     0.000441
# LoadConfigurationSize                  -0.000178  ... -0.001908    -0.003085
# VersionInformationSize                 -0.007810  ...  0.025281     0.035188
#
#                              ResourcesMeanEntropy  ResourcesMinEntropy  \
# ID                                       0.250975            -0.075881
# Machine                                 -0.023421             0.101036
# SizeOfOptionalHeader                    -0.024565             0.098774
# Characteristics                         -0.046706            -0.013781
# MajorLinkerVersion                       0.071237             0.140788
# MinorLinkerVersion                      -0.038857            -0.076242
# SizeOfCode                              -0.005500            -0.004692
# SizeOfInitializedData                   -0.002709            -0.007036
# SizeOfUninitializedData                 -0.001735            -0.007986
# AddressOfEntryPoint                     -0.002294            -0.011891
# BaseOfCode                              -0.000450            -0.003219
# BaseOfData                               0.011203            -0.005486
# ImageBase                               -0.001039             0.006713
# SectionAlignment                        -0.000179            -0.004265
# FileAlignment                           -0.103322            -0.043143
# MajorOperatingSystemVersion              0.000651             0.006436
# MinorOperatingSystemVersion             -0.006179            -0.000191
# MajorImageVersion                       -0.002968             0.030497
# MinorImageVersion                       -0.002278             0.030735
# MajorSubsystemVersion                    0.080891             0.204116
# MinorSubsystemVersion                   -0.008407            -0.006360
# SizeOfImage                              0.006581            -0.048124
# SizeOfHeaders                           -0.018800            -0.031608
# CheckSum                                 0.111229            -0.001059
# Subsystem                               -0.078040             0.209642
# DllCharacteristics                       0.238060             0.040709
# SizeOfStackReserve                      -0.006360            -0.004935
# SizeOfStackCommit                       -0.006359            -0.004931
# SizeOfHeapReserve                       -0.006148            -0.004631
# SizeOfHeapCommit                        -0.004965             0.000809
# LoaderFlags                             -0.009263            -0.003680
# NumberOfRvaAndSizes                     -0.007788            -0.006468
# SectionsNb                               0.037003            -0.029296
# SectionsMeanEntropy                      0.261474            -0.100897
# SectionsMinEntropy                       0.164450            -0.051530
# SectionsMaxEntropy                       0.252008            -0.143232
# SectionsMeanRawsize                     -0.000103            -0.013145
# SectionsMinRawsize                       0.015680            -0.057157
# SectionMaxRawsize                       -0.000753            -0.008766
# SectionsMeanVirtualsize                  0.009142            -0.025747
# SectionsMinVirtualsize                   0.015979            -0.062839
# SectionMaxVirtualsize                    0.004571            -0.022978
# ImportsNbDLL                             0.084541            -0.106191
# ImportsNb                                0.041793            -0.162981
# ImportsNbOrdinal                        -0.009191            -0.073201
# ExportNb                                -0.018927            -0.006099
# ResourcesNb                              0.046293            -0.174090
# ResourcesMeanEntropy                     1.000000             0.475010
# ResourcesMinEntropy                      0.475010             1.000000
# ResourcesMaxEntropy                      0.784051             0.064602
# ResourcesMeanSize                       -0.000581             0.003618
# ResourcesMinSize                        -0.001119             0.004198
# ResourcesMaxSize                        -0.000090            -0.000692
# LoadConfigurationSize                   -0.036378            -0.039294
# VersionInformationSize                   0.165454             0.088854
#
#                              ResourcesMaxEntropy  ResourcesMeanSize  \
# ID                                      0.335122          -0.000788
# Machine                                -0.079459          -0.001601
# SizeOfOptionalHeader                   -0.079658          -0.001587
# Characteristics                        -0.077261          -0.002910
# MajorLinkerVersion                      0.022779          -0.000004
# MinorLinkerVersion                     -0.028155          -0.001468
# SizeOfCode                             -0.003430           0.000245
# SizeOfInitializedData                   0.001968          -0.000007
# SizeOfUninitializedData                 0.006992          -0.000082
# AddressOfEntryPoint                     0.000981          -0.000031
# BaseOfCode                             -0.002046          -0.000042
# BaseOfData                              0.011893          -0.000152
# ImageBase                              -0.005248          -0.000035
# SectionAlignment                        0.000486          -0.000032
# FileAlignment                          -0.120929           0.001185
# MajorOperatingSystemVersion            -0.002540          -0.000035
# MinorOperatingSystemVersion            -0.008573          -0.000031
# MajorImageVersion                      -0.024085          -0.000217
# MinorImageVersion                      -0.023577          -0.000189
# MajorSubsystemVersion                  -0.009202          -0.001117
# MinorSubsystemVersion                  -0.008255          -0.000015
# SizeOfImage                             0.042304          -0.000038
# SizeOfHeaders                          -0.018505           0.000204
# CheckSum                                0.180401          -0.000711
# Subsystem                              -0.230236          -0.002118
# DllCharacteristics                      0.315990          -0.006076
# SizeOfStackReserve                     -0.005936          -0.000012
# SizeOfStackCommit                      -0.005938          -0.000013
# SizeOfHeapReserve                      -0.005806          -0.000013
# SizeOfHeapCommit                       -0.007286          -0.000030
# LoaderFlags                            -0.010893          -0.000039
# NumberOfRvaAndSizes                    -0.006953          -0.000027
# SectionsNb                              0.088350           0.005492
# SectionsMeanEntropy                     0.317994           0.001597
# SectionsMinEntropy                      0.143802          -0.002481
# SectionsMaxEntropy                      0.347951           0.000807
# SectionsMeanRawsize                     0.003733           0.000035
# SectionsMinRawsize                      0.041482           0.001362
# SectionMaxRawsize                       0.001404          -0.000005
# SectionsMeanVirtualsize                 0.023794           0.000071
# SectionsMinVirtualsize                  0.045191           0.001470
# SectionMaxVirtualsize                   0.022759          -0.000028
# ImportsNbDLL                            0.185999          -0.004139
# ImportsNb                               0.209449          -0.003830
# ImportsNbOrdinal                        0.051442           0.000492
# ExportNb                               -0.022252          -0.000411
# ResourcesNb                             0.141270          -0.000769
# ResourcesMeanEntropy                    0.784051          -0.000581
# ResourcesMinEntropy                     0.064602           0.003618
# ResourcesMaxEntropy                     1.000000          -0.002399
# ResourcesMeanSize                      -0.002399           1.000000
# ResourcesMinSize                       -0.003927           0.978651
# ResourcesMaxSize                        0.003666           0.802534
# LoadConfigurationSize                  -0.029453          -0.000090
# VersionInformationSize                  0.085636          -0.003825
#
#                              ResourcesMinSize  ResourcesMaxSize  \
# ID                                  -0.001749          0.002856
# Machine                             -0.001298         -0.002483
# SizeOfOptionalHeader                -0.001287         -0.002463
# Characteristics                     -0.002365         -0.003526
# MajorLinkerVersion                   0.000196         -0.000483
# MinorLinkerVersion                  -0.001460         -0.000527
# SizeOfCode                           0.000268          0.000164
# SizeOfInitializedData               -0.000060          0.001065
# SizeOfUninitializedData             -0.000063         -0.000109
# AddressOfEntryPoint                 -0.000018          0.000295
# BaseOfCode                          -0.000038          0.000199
# BaseOfData                          -0.000145          0.000382
# ImageBase                           -0.000026         -0.000063
# SectionAlignment                    -0.000029         -0.000046
# FileAlignment                        0.000620          0.003513
# MajorOperatingSystemVersion         -0.000024         -0.000069
# MinorOperatingSystemVersion         -0.000020         -0.000064
# MajorImageVersion                   -0.000236         -0.000315
# MinorImageVersion                   -0.000228         -0.000160
# MajorSubsystemVersion               -0.000310         -0.003337
# MinorSubsystemVersion               -0.000007         -0.000041
# SizeOfImage                         -0.000272          0.004981
# SizeOfHeaders                        0.000059          0.000913
# CheckSum                            -0.001021          0.000983
# Subsystem                           -0.001779         -0.003499
# DllCharacteristics                  -0.004981         -0.008530
# SizeOfStackReserve                  -0.000009         -0.000022
# SizeOfStackCommit                   -0.000009         -0.000022
# SizeOfHeapReserve                   -0.000009         -0.000023
# SizeOfHeapCommit                    -0.000022         -0.000054
# LoaderFlags                         -0.000029         -0.000070
# NumberOfRvaAndSizes                 -0.000021          0.000010
# SectionsNb                           0.006349          0.002112
# SectionsMeanEntropy                  0.000386          0.004054
# SectionsMinEntropy                  -0.003536         -0.000319
# SectionsMaxEntropy                   0.000170          0.002640
# SectionsMeanRawsize                 -0.000086          0.001201
# SectionsMinRawsize                  -0.000246          0.004783
# SectionMaxRawsize                   -0.000065          0.001182
# SectionsMeanVirtualsize             -0.000174          0.002622
# SectionsMinVirtualsize              -0.000272          0.005090
# SectionMaxVirtualsize               -0.000180          0.003095
# ImportsNbDLL                        -0.003358         -0.004274
# ImportsNb                           -0.003467         -0.002415
# ImportsNbOrdinal                    -0.000544          0.007646
# ExportNb                            -0.000314         -0.000658
# ResourcesNb                         -0.000660          0.000441
# ResourcesMeanEntropy                -0.001119         -0.000090
# ResourcesMinEntropy                  0.004198         -0.000692
# ResourcesMaxEntropy                 -0.003927          0.003666
# ResourcesMeanSize                    0.978651          0.802534
# ResourcesMinSize                     1.000000          0.690929
# ResourcesMaxSize                     0.690929          1.000000
# LoadConfigurationSize               -0.000082         -0.000148
# VersionInformationSize              -0.004147         -0.002567
#
#                              LoadConfigurationSize  VersionInformationSize
# ID                                       -0.007060                0.511307
# Machine                                  -0.006600                0.231100
# SizeOfOptionalHeader                     -0.006543                0.227293
# Characteristics                          -0.005389                0.020352
# MajorLinkerVersion                        0.016880               -0.027587
# MinorLinkerVersion                       -0.000989               -0.190963
# SizeOfCode                               -0.000263               -0.006280
# SizeOfInitializedData                    -0.000326               -0.006692
# SizeOfUninitializedData                  -0.000386               -0.017376
# AddressOfEntryPoint                      -0.000178               -0.007810
# BaseOfCode                               -0.000170               -0.003153
# BaseOfData                               -0.000287               -0.003668
# ImageBase                                -0.000130                0.000087
# SectionAlignment                         -0.000145               -0.001479
# FileAlignment                            -0.004864               -0.102698
# MajorOperatingSystemVersion              -0.000085               -0.004199
# MinorOperatingSystemVersion              -0.000146               -0.005053
# MajorImageVersion                        -0.001190                0.021126
# MinorImageVersion                        -0.001155                0.019696
# MajorSubsystemVersion                     0.003243               -0.001642
# MinorSubsystemVersion                    -0.000115               -0.001612
# SizeOfImage                              -0.000713               -0.005443
# SizeOfHeaders                             0.001754               -0.028075
# CheckSum                                 -0.003531               -0.170732
# Subsystem                                -0.007187               -0.012277
# DllCharacteristics                       -0.005894                0.105111
# SizeOfStackReserve                       -0.000034               -0.002110
# SizeOfStackCommit                        -0.000034               -0.002108
# SizeOfHeapReserve                        -0.000037               -0.002320
# SizeOfHeapCommit                         -0.000109               -0.005145
# LoaderFlags                               0.000084               -0.006604
# NumberOfRvaAndSizes                      -0.000103               -0.004464
# SectionsNb                               -0.004594                0.043846
# SectionsMeanEntropy                       0.033943                0.148718
# SectionsMinEntropy                        0.032153                0.158834
# SectionsMaxEntropy                        0.016271                0.175605
# SectionsMeanRawsize                      -0.000261               -0.003400
# SectionsMinRawsize                       -0.000981                0.016140
# SectionMaxRawsize                        -0.000244               -0.004183
# SectionsMeanVirtualsize                  -0.000233               -0.003229
# SectionsMinVirtualsize                   -0.000968                0.014377
# SectionMaxVirtualsize                    -0.000380               -0.005055
# ImportsNbDLL                             -0.018516               -0.073677
# ImportsNb                                -0.015835                0.010101
# ImportsNbOrdinal                         -0.002681                0.015182
# ExportNb                                 -0.001908                0.025281
# ResourcesNb                              -0.003085                0.035188
# ResourcesMeanEntropy                     -0.036378                0.165454
# ResourcesMinEntropy                      -0.039294                0.088854
# ResourcesMaxEntropy                      -0.029453                0.085636
# ResourcesMeanSize                        -0.000090               -0.003825
# ResourcesMinSize                         -0.000082               -0.004147
# ResourcesMaxSize                         -0.000148               -0.002567
# LoadConfigurationSize                     1.000000               -0.019929
# VersionInformationSize                   -0.019929                1.000000
#
# [55 rows x 55 columns]

# %%
# correlation = dataset.corr()
# pyplot.figure(figsize = (30, 30))
# sb.heatmap(correlation, vmax = 1, square = True, annot = True, cmap = 'summer')

# pyplot.title('Correlation between different features:')

# %%
X_vals = dataset.iloc[:,:].values #
y_vals = y_vals.values
# print("X_vals", X_vals.shape)
# print("Y_vals:", y_vals)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
print(scaler.fit(X_vals))
MinMaxScaler()
max_data = scaler.data_max_
norm_data = scaler.transform(X_vals)
# print(numpy.argwhere(numpy.isnan(norm_data)))
norm_data[13][4] = 0
# print("Max Value:", max_data)
# print()
# print("Normalized Data: ", norm_data.shape)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(norm_data, y_vals, test_size = 0.2, random_state = 0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.3, random_state = 0)
print("X-Train Shape:", X_train.shape)
print("X-Test Shape:", X_test.shape)
print("X-val Shape:", X_val.shape)
print("y train Shape:", y_train.shape)
print("y test shape:", y_test.shape)
print("y val shape:", y_val.shape)
# Out:
# X-Train Shape: (121156, 55)
# X-Test Shape: (43271, 55)
# X-val Shape: (51925, 55)
# y train Shape: (121156,)
# y test shape: (43271,)
# y val shape: (51925,)

# %%
# kfold = KFold(3, shuffle=True, random_state=1)
# for train_index, val_index in kfold.split(X_train):
#     X_train, X_val, y_train, y_val = X_train[train_index], X_train[val_index], y_train[train_index], y_train[val_index]

# %%
pca = PCA(X_train.shape[1])
pca.fit(X_train)
# print(pca.components_.T)
# print(pca.explained_variance_ratio_)
print('Number of components:', pca.explained_variance_ratio_.shape[0] )
# Out:
# Number of components: 55

# %%
n_comp = numpy.arange(55)
n_comp = n_comp+1
cumulative = numpy.cumsum(pca.explained_variance_ratio_)
from matplotlib.pyplot import figure, show
from matplotlib.ticker import MaxNLocator
ax = figure().gca()
ax.plot(n_comp,cumulative)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('Principal Components')
plt.ylabel('Cumulative % of Retained Variance')
show()

# %%
pca = PCA(n_components = 12)
X_new_vals = pca.fit_transform(X_train)
X_new_test = pca.fit_transform(X_test)
X_new_vali = pca.fit_transform(X_val)
print('Variance Retained:', sum(pca.explained_variance_ratio_))
# print(X_new_vals)
# print(X_new_vals.shape)
# Out:
# Variance Retained: 0.9847184017795353

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_val = to_categorical(y_val)

# %%
print(y_train.shape)
# Out:
# (121156, 2)

# %%
# Create model
model = Sequential()
model.add(Dense(32, input_dim=12, kernel_initializer='normal', activation='relu'))
model.add(Dense(16, kernel_initializer='normal', activation='relu'))
model.add(Dense(8, kernel_initializer='normal', activation='relu'))
model.add(Dense(2, kernel_initializer='normal', activation='sigmoid'))
opt = SGD(lr=0.01,momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_new_vals,y_train,epochs=10,batch_size=100)
# Out:
# Epoch 1/10
# 121156/121156 [==============================] - 3s 27us/step - loss: 0.6481 - accuracy: 0.6516
# Epoch 2/10
# 121156/121156 [==============================] - 3s 23us/step - loss: 0.6464 - accuracy: 0.6517
# Epoch 3/10
# 121156/121156 [==============================] - 3s 23us/step - loss: 0.6464 - accuracy: 0.6517
# Epoch 4/10
# 121156/121156 [==============================] - 4s 31us/step - loss: 0.6462 - accuracy: 0.6517
# Epoch 5/10
# 121156/121156 [==============================] - 3s 24us/step - loss: 0.5641 - accuracy: 0.7174
# Epoch 6/10
# 121156/121156 [==============================] - 3s 24us/step - loss: 0.0769 - accuracy: 0.9859
# Epoch 7/10
# 121156/121156 [==============================] - 3s 24us/step - loss: 0.0431 - accuracy: 0.9900
# Epoch 8/10
# 121156/121156 [==============================] - 3s 24us/step - loss: 0.0329 - accuracy: 0.9930
# Epoch 9/10
# 121156/121156 [==============================] - 3s 24us/step - loss: 0.0289 - accuracy: 0.9939
# Epoch 10/10
# 121156/121156 [==============================] - 3s 24us/step - loss: 0.0266 - accuracy: 0.9944

# %%
accuracy = model.evaluate(X_new_test, y_test)
print(accuracy)
# Out:
# 43271/43271 [==============================] - 1s 31us/step
# [0.29178887794759756, 0.9380647540092468]

# %%
plt.plot(history.history['loss'])

# %%
def tuned_model(L=1, N=32, a_h='sigmoid', a_o='softmax'):
    model = Sequential()
    model.add(Dense(N, input_dim=12, kernel_initializer='normal', activation=a_h))
    for i in range(L):
        model.add(Dense(N, kernel_initializer='normal', activation=a_h))
    model.add(Dense(2, kernel_initializer='normal', activation=a_o))
    opt = SGD(lr=0.01,momentum=0.9)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
predictor = KerasClassifier(build_fn=tuned_model, epochs=10, batch_size=100, verbose=0)

# %%
layers = [1,2,3,4,5]
neurons = [32,64,128]
a_h = ['sigmoid', 'relu']
a_o = ['sigmoid', 'softmax']
param_grid = dict(L=layers, N=neurons, a_h=a_h, a_o=a_o)
grid = GridSearchCV(estimator=predictor, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_new_vali, y_val) #Use validation set obtained by kfold split
